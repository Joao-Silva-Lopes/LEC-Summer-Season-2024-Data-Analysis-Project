# %% [markdown]
# # Introduction
#
# Welcome to the LEC Summer Season 2024 Data Analysis Project! This project aims to provide a comprehensive analysis of the performance of players and teams during the LEC Summer Season of 2024. By examining various metrics and statistics, we seek to uncover insights into player performance, champion picks, and strategic decisions made throughout the season. Here is an overview of what you can expect from this project:
#
# ## Player Performance Analysis
# #### - Identify the top-performing players based on KDA (Kill/Death/Assist) ratio.
# #### - Highlight players with the highest number of kills, deaths, and assists.
# #### - Analyze player performance across different roles (Top, Jungle, Mid, ADC, Support).
#
# ## Team Performance Analysis
# #### - Focus on specific teams, such as SK, to understand their strengths and weaknesses.
# #### - Determine which champions were most effective for each role within the team.
#
# ## Champion Picks and Bans
# #### - Investigate the most picked and banned champions during the season.
# #### - Understand the impact of specific champion picks on game outcomes.
#
# ## Match Analysis
# #### - Review key matches to identify significant moments and turning points.
# #### - Compare player performances in different matches to identify consistency and variability.
#
# ## Statistical Insights
# #### - Provide statistical summaries and visualizations to illustrate key findings.
# #### - Use data-driven insights to make recommendations for future strategies.
#
# This project leverages data from the LEC Summer Season 2024 to provide a detailed and informative analysis, offering valuable insights for players, teams, analysts, and fans. Let's dive into the data and uncover the stories behind the numbers!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Upload the Excel file for analysis

file_path = r'C:\Users\joaov\Documents\LEC project\LEC_SummerSeason_2024.xlsx'

df = pd.read_excel(file_path)

# %% [markdown]
# # Dataframe analysis

# %% [markdown]
# #### Let's analyze the first 5 data from the DF

# %%
df.head()
# Out:
#     Player     Role Team Opponent_Team Opponent_Player                 Date  \
# 0   Wunder      TOP   TH            GX      Th3Antonio  2024-08-06 00:00:00
# 1   Jankos   JUNGLE   TH            GX           Juhan  2024-08-06 00:00:00
# 2   Zwyroo      MID   TH            GX         Jackies  2024-08-06 00:00:00
# 3  Flakked  ADCARRY   TH            GX          Patrik  2024-08-06 00:00:00
# 4   Trymbi  SUPPORT   TH            GX           IgNar  2024-08-06 00:00:00
#
#               Stage  Side      Time           Ban  ... Damage self mitigated  \
# 0  Summer_Season_24  Blue  00:38:40        Lucian  ...               46151.0
# 1  Summer_Season_24  Blue  00:38:40       Skarner  ...               41792.0
# 2  Summer_Season_24  Blue  00:38:40        Rumble  ...                6100.0
# 3  Summer_Season_24  Blue  00:38:40          Ashe  ...                8704.0
# 4  Summer_Season_24  Blue  00:38:40  Renata_Glasc  ...               22101.0
#
#   Total Damage Shielded On Teammates Time ccing others Total Time CC Dealt  \
# 0                              490.0              52.0              1915.0
# 1                                0.0              21.0               653.0
# 2                                0.0              40.0               655.0
# 3                                0.0               1.0                52.0
# 4                              442.0              42.0               183.0
#
#   Total damage taken Total Time Spent Dead  Consumables purchased  \
# 0            28359.0                   0.0                    9.0
# 1            48827.0                  90.0                   12.0
# 2            11396.0                  46.0                   10.0
# 3            13181.0                  40.0                   11.0
# 4            10141.0                  26.0                   15.0
#
#    Items Purchased  Shutdown bounty collected  Shutdown bounty lost
# 0             29.0                        0.0                   0.0
# 1             32.0                        0.0                   0.0
# 2             31.0                       50.0                  50.0
# 3             32.0                       50.0                 150.0
# 4             34.0                       50.0                   0.0
#
# [5 rows x 74 columns]

# %% [markdown]
# #### Let's look at the name of all the columns

# %%
print(df.columns)
# Out:
# Index(['Player', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Date',
#        'Stage', 'Side', 'Time', 'Ban', 'Ban_Opponent', 'Pick', 'Pick_Opponent',
#        'Champion', 'Champion_Opponent', 'Outcome', 'Kills_Team',
#        'Turrets_Team', 'Dragon_Team', 'Baron_Team', 'Level', 'Kills', 'Deaths',
#        'Assists', 'KDA', 'CS', 'CS in Team's Jungle', 'CS in Enemy Jungle',
#        'CSM', 'Golds', 'GPM', 'GOLD%', 'Vision Score', 'Wards placed',
#        'Wards destroyed', 'Control Wards Purchased', 'Detector Wards Placed',
#        'VSPM', 'WPM', 'VWPM', 'WCPM', 'VS%', 'Total damage to Champion',
#        'Physical Damage', 'Magic Damage', 'True Damage', 'DPM', 'DMG%',
#        'K+A Per Minute', 'KP%', 'Solo kills', 'Double kills', 'Triple kills',
#        'Quadra kills', 'Penta kills', 'GD@15', 'CSD@15', 'XPD@15', 'LVLD@15',
#        'Objectives Stolen', 'Damage dealt to turrets',
#        'Damage dealt to buildings', 'Total heal', 'Total Heals On Teammates',
#        'Damage self mitigated', 'Total Damage Shielded On Teammates',
#        'Time ccing others', 'Total Time CC Dealt', 'Total damage taken',
#        'Total Time Spent Dead', 'Consumables purchased', 'Items Purchased',
#        'Shutdown bounty collected', 'Shutdown bounty lost'],
#       dtype='object')

# %% [markdown]
# # Let's analyze the data

# %% [markdown]
# ##### Let's select the column we are going to use

# %%
df_top_player = ['Player', 'Role', 'Team', 'Champion', 'Pick', 'Kills', 'Deaths', 'Assists', 'Opponent_Team', 'Opponent_Player', 'Champion_Opponent','Total damage to Champion']

df_top_player = df[df_top_player]

# %% [markdown]
# #### Let's find the player with the most kills and who he was against in the match

# %%
# Find the player with the most kills
top_kills = df_top_player.loc[df_top_player['Kills'].idxmax()]

# Display results
print("Player with the most kills:")
print(top_kills[['Player', 'Team','Role', 'Champion', 'Kills', 'Deaths', 'Assists', 'Opponent_Team', 'Opponent_Player', 'Champion_Opponent', 'Total damage to Champion']])
# Out:
# Player with the most kills:
# Player                        Flakked
# Team                               TH
# Role                          ADCARRY
# Champion                         Zeri
# Kills                              13
# Deaths                              4
# Assists                             3
# Opponent_Team                      G2
# Opponent_Player             Hans_Sama
# Champion_Opponent             Caitlyn
# Total damage to Champion      49927.0
# Name: 433, dtype: object

# %% [markdown]
# #### We can see that the player Flakked was the player with the most kills, this is very interesting, as we can watch his game against G2 and see how he played to reach this KDA

# %% [markdown]
# ### Let's find the player with the most deaths and who he was in the match against

# %%
# Find the player with the highest number of deaths
top_deaths = df_top_player.loc[df_top_player['Deaths'].idxmax()]

# Display results
print("Player with the most deaths:")
print(top_deaths[['Player', 'Team','Role', 'Champion', 'Kills', 'Deaths', 'Assists', 'Opponent_Team', 'Opponent_Player', 'Champion_Opponent', 'Total damage to Champion']])
# Out:
# Player with the most deaths:
# Player                             Mikyx
# Team                                  G2
# Role                             SUPPORT
# Champion                           Poppy
# Kills                                  4
# Deaths                                 9
# Assists                                6
# Opponent_Team                         SK
# Opponent_Player                     Luon
# Champion_Opponent           Renata_Glasc
# Total damage to Champion         12245.0
# Name: 94, dtype: object

# %% [markdown]
# #### We can see that Mikyx was the one who died the most in the match against SK, why is that? You can watch the match and see what happened in the game

# %% [markdown]
# ### Let's find the player with the most assists and who he was against in the match

# %%
# Find the player with the most assists

top_assists = df_top_player.loc[df_top_player['Assists'].idxmax()]


# Display results
print("Player with the most assists:")
print(top_assists[['Player', 'Team', 'Role', 'Champion', 'Kills', 'Deaths', 'Assists', 'Opponent_Team', 'Opponent_Player', 'Champion_Opponent', 'Total damage to Champion']])
# Out:
# Player with the most assists:
# Player                             Mikyx
# Team                                  G2
# Role                             SUPPORT
# Champion                    Renata_Glasc
# Kills                                  0
# Deaths                                 4
# Assists                               19
# Opponent_Team                        FNC
# Opponent_Player                      Jun
# Champion_Opponent                  Leona
# Total damage to Champion         11858.0
# Name: 329, dtype: object

# %% [markdown]
# ##### Now with the highest number of assists the probability of being Support is high, and we can see that in a match he was the one who died the most and now he was the one who gave the most assists, so we can analyze the 2 matches and see if it fluctuates a lot in gameplay

# %% [markdown]
# ## Let's analyze the 10 most attacked and banned champions during the championship

# %%
df_porcentagem_de_campeao = ['Ban', 'Ban_Opponent', 'Pick', 'Pick_Opponent','Outcome']
df_porcentagem_de_campeao = df[df_porcentagem_de_campeao]

# Count the frequency of each champion in the 'Pick' column

top_picks = df_porcentagem_de_campeao['Pick'].value_counts().head(10)
top_picks_opponent = df_porcentagem_de_campeao['Pick_Opponent'].value_counts().head(10)

# Count the frequency of each champion in the 'Ban' column

top_bans = df_porcentagem_de_campeao['Ban'].value_counts().head(10)
top_bans_opponent = df_porcentagem_de_campeao['Ban_Opponent'].value_counts().head(10)

# Combine picks and bans

top_picks_combined = pd.concat([top_picks, top_picks_opponent], axis=1, keys=['Pick', 'Pick_Opponent']).fillna(0).sum(axis=1).sort_values(ascending=False).head(10)
top_bans_combined = pd.concat([top_bans, top_bans_opponent], axis=1, keys=['Ban', 'Ban_Opponent']).fillna(0).sum(axis=1).sort_values(ascending=False).head(10)

# Add win and loss columns for picks

top_picks_combined = top_picks_combined.to_frame(name='Total_Picks')
top_picks_combined['Wins'] = 0
top_picks_combined['Losses'] = 0

# Count wins and losses for each champion in the picks

for champ in top_picks_combined.index:
    top_picks_combined.at[champ, 'Wins'] = (
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Pick'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Win')].shape[0] +
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Pick_Opponent'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Loss')].shape[0]
    )
    top_picks_combined.at[champ, 'Losses'] = (
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Pick'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Loss')].shape[0] +
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Pick_Opponent'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Win')].shape[0]
    )

# Calculate winning percentage for picks

top_picks_combined['Win_Percentage'] = (top_picks_combined['Wins'] / top_picks_combined['Total_Picks']) * 100


# Format win percentage with two decimal places for picks

top_picks_combined['Win_Percentage'] = top_picks_combined['Win_Percentage'].map(lambda x: f'{x:.2f}%')

# Add win and loss columns for bans

top_bans_combined = top_bans_combined.to_frame(name='Total_Bans')
top_bans_combined['Wins'] = 0
top_bans_combined['Losses'] = 0

# Count wins and losses for each champion in bans

for champ in top_bans_combined.index:
    top_bans_combined.at[champ, 'Wins'] = (
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Ban'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Win')].shape[0] +
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Ban_Opponent'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Loss')].shape[0]
    )
    top_bans_combined.at[champ, 'Losses'] = (
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Ban'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Loss')].shape[0] +
        df_porcentagem_de_campeao[(df_porcentagem_de_campeao['Ban_Opponent'] == champ) & (df_porcentagem_de_campeao['Outcome'] == 'Win')].shape[0]
    )

# Calcular porcentagem de vitórias para bans
top_bans_combined['Win_Percentage'] = (top_bans_combined['Wins'] / top_bans_combined['Total_Bans']) * 100

# Formatar porcentagem de vitórias com duas casas decimais para bans
top_bans_combined['Win_Percentage'] = top_bans_combined['Win_Percentage'].map(lambda x: f'{x:.2f}%')

# %% [markdown]
# #### Show results

# %%
print("Top 10 Most Picked Champions (with Wins and Losses):")
top_picks_combined.head(10)
# Out:
# Top 10 Most Picked Champions (with Wins and Losses):
#           Total_Picks  Wins  Losses Win_Percentage
# Rell               50    30      20         60.00%
# Corki              48    22      26         45.83%
# Sejuani            46    24      22         52.17%
# Taliyah            46    32      14         69.57%
# Nautilus           36    16      20         44.44%
# KSante             34    16      18         47.06%
# Zeri               34    18      16         52.94%
# Kaisa              32    20      12         62.50%
# Varus              32    12      20         37.50%
# Azir               30    18      12         60.00%

# %% [markdown]
# #### We can see from the results that Rell, Corki and Sejuani are the most popular characters in the tournament and Rell continues to have a high winrate%, so she is a champion to keep an eye on

# %%
print("Top 10 Most Banned Champions (with Wins and Losses):")
top_bans_combined.head(10)
# Out:
# Top 10 Most Banned Champions (with Wins and Losses):
#               Total_Bans  Wins  Losses Win_Percentage
# Skarner             80.0    38      42         47.50%
# Rumble              78.0    42      36         53.85%
# Twisted_Fate        56.0    16      40         28.57%
# Vi                  54.0    32      22         59.26%
# Ivern               46.0    26      20         56.52%
# LeBlanc             36.0    18      18         50.00%
# Tristana            34.0    10      24         29.41%
# Nautilus            28.0    26       2         92.86%
# Sejuani             24.0    10      14         41.67%
# Renekton            12.0     8      16         66.67%

# %% [markdown]
# ##### And if we look at the most banned champions Snaker and Rumble have a high ban rate, but if you look closely even when they catch them, the win rate is not that high

# %% [markdown]
# ## Analyzing if any player made a Pental Kill or Quadra kill, and did he win after making these kills?

# %%
# Assuming that df is the DataFrame with the match data
df_penta_kill = df[['Player', 'Champion', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Triple kills', 'Quadra kills', 'Penta kills', 'Outcome']]

# Remove NA values ​​to avoid problems with kill counts
df_penta_kill = df_penta_kill.fillna(0)

# Convert kill counts to integers
df_penta_kill['Penta kills'] = df_penta_kill['Penta kills'].astype(int)

# Filtrar jogadores que fizeram Triple kills, Quadra kills ou Penta kills
df_penta_kill_filtered = df_penta_kill[df_penta_kill['Penta kills'] > 0]

# Filter players who have made Triple kills, Quadra kills or Penta kills
df_penta_kill_filtered = df_penta_kill_filtered[['Player', 'Champion', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Penta kills', 'Outcome']]

# Rename columns for clarity
df_penta_kill_filtered.columns = ['Player', 'Champion', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Penta_Kills', 'Outcome']

# Exibir resultados

print("Players with Penta kills:")
df_penta_kill_filtered.head()
# Out:
# Players with Penta kills:
#    Player Champion     Role Team Opponent_Team Opponent_Player  Penta_Kills  \
# 53    Ice     Jinx  ADCARRY  BDS            TH         Flakked            1
#
#    Outcome
# 53     Win

# %% [markdown]
# ##### We found a player, Ice, against the TH team, and he won the match, which means if you do a Pental Kill the chance of winning a tournament match is very high

# %%
df_penta_kill['Quadra kills'] = df_penta_kill['Quadra kills'].astype(int)
df_quadra_kill = df_penta_kill[df_penta_kill['Quadra kills'] > 0]
df_quadra_kill = df_quadra_kill[['Player', 'Champion', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Quadra kills', 'Outcome']]

df_quadra_kill.head()
# Out:
#     Player Champion     Role Team Opponent_Team Opponent_Player  Quadra kills  \
# 148   Supa     Jinx  ADCARRY  MDK            TH         Flakked             1
# 343  Upset    Kaisa  ADCARRY   KC           VIT          Carzzy             1
#
#     Outcome
# 148     Win
# 343     Win

# %% [markdown]
# ##### Here we already noticed that 2 players made Quadra Kills and they won the match too, 1 Penta and 1 Quadra with the character Jinx, so we can watch the matches to see what the players did to get these kills

# %% [markdown]
# ## Let's analyze the top 10 players with the most Gold

# %% [markdown]
# #### We can see that the player Flakked was the player with the most kills, this is very interesting, as we can watch his game against G2 and see how he played to reach this KDA

# %%
df_gold_partida = df[['Player', 'Role', 'Team', 'Champion', 'Golds', 'Outcome']]

# Remove NA values ​​to avoid problems when calculating top players
df_gold_partida = df_gold_partida.dropna(subset=['Golds'])

# Convert the 'Golds' column to numeric if necessary
df_gold_partida['Golds'] = pd.to_numeric(df_gold_partida['Golds'], errors='coerce')

# Sort the DataFrame by the 'Golds' column in descending order and select the top 10
top_10_gold = df_gold_partida.sort_values(by='Golds', ascending=False).head(10)

# Display the DataFrame with the top 10 players
top_10_gold.head(10)
# Out:
#         Player     Role Team Champion    Golds Outcome
# 413       Supa  ADCARRY  MDK     Zeri  23374.0     Win
# 433    Flakked  ADCARRY   TH     Zeri  22135.0    Loss
# 118      Rahel  ADCARRY   SK   Lucian  21765.0     Win
# 123        Ice  ADCARRY  BDS     Jinx  21239.0     Win
# 62     Larssen      MID  RGE     Azir  20791.0     Win
# 68      Carzzy  ADCARRY  VIT    Ziggs  20472.0    Loss
# 248        Ice  ADCARRY  BDS     Zeri  20333.0     Win
# 73       Upset  ADCARRY   KC     Jinx  20091.0     Win
# 78        Supa  ADCARRY  MDK     Ashe  19886.0    Loss
# 438  Hans_Sama  ADCARRY   G2  Caitlyn  19772.0     Win

# %% [markdown]
# ##### Looking at the players who obtained the most Golds, a good % is ADC, so it is a very interesting route to be farming to become strong and the most used champions are very Late Game

# %% [markdown]
# ### Top 10 Players who had a Perfect KDA in the match

# %%
df_kda_perfeito = df[['Player', 'Role', 'Team', 'Champion', 'Outcome', 'KDA', 'Opponent_Team']]


# Filter players with Perfect KDA
perfect_kda = df_kda_perfeito[df_kda_perfeito['KDA'] == 'Perfect_KDA']

# Select the top 10 players with Perfect KDA
top_10_perfect_kda = perfect_kda.head(10)


# Display the DataFrame with the top 10 players with Perfect KDA
top_10_perfect_kda.head(10)
# Out:
#        Player     Role Team  Champion Outcome          KDA Opponent_Team
# 0      Wunder      TOP   TH    KSante     Win  Perfect_KDA            GX
# 21     Lyncas   JUNGLE  VIT    Lillia    Loss  Perfect_KDA           BDS
# 27        nuc      MID  BDS   Taliyah     Win  Perfect_KDA           VIT
# 28        Ice  ADCARRY  BDS     Senna     Win  Perfect_KDA           VIT
# 29     Labrov  SUPPORT  BDS  Nautilus     Win  Perfect_KDA           VIT
# 47   Humanoid      MID  FNC      Hwei     Win  Perfect_KDA            KC
# 62    Larssen      MID  RGE      Azir     Win  Perfect_KDA           VIT
# 81     Razork   JUNGLE  FNC     Ivern     Win  Perfect_KDA            GX
# 101    Razork   JUNGLE  FNC  Xin_Zhao     Win  Perfect_KDA           VIT
# 103      Noah  ADCARRY  FNC  Aphelios     Win  Perfect_KDA           VIT

# %% [markdown]
# ##### Looking at this table, the FNC team had 4 Perfect KDA, this is interesting, to take a look at the players, what are they doing in the match to achieve this Perfect KDA?

# %% [markdown]
# ### Which will be the 5 teams with the most wins and the 5 teams with the most losses

# %%
df_melhores_times = df[['Team', 'Opponent_Team', 'Outcome']]

# Count the number of wins and losses for each team
win_counts = df_melhores_times[df_melhores_times['Outcome'] == 'Win']['Team'].value_counts()
loss_counts = df_melhores_times[df_melhores_times['Outcome'] == 'Loss']['Team'].value_counts()

# Select the 5 teams with the most wins and the 5 teams with the most losses
top_5_wins = win_counts.head(5)
top_5_losses = loss_counts.head(5)

# Create DataFrames for easier viewing
top_5_wins_df = pd.DataFrame({'Team': top_5_wins.index, 'Wins': top_5_wins.values})
top_5_losses_df = pd.DataFrame({'Team': top_5_losses.index, 'Losses': top_5_losses.values})

# Configure the chart
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Chart of teams with the most wins
bars_wins = ax[0].bar(top_5_wins_df['Team'], top_5_wins_df['Wins'], color='green')
ax[0].set_title('Top 5 Teams with the Most Wins')
ax[0].set_xlabel('Teams')
ax[0].set_ylabel('Number of Wins')

# Add the values ​​on top of the win bars
for bar in bars_wins:
    yval = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')  # va='bottom' coloca o texto acima da barra

# Chart of teams with the most defeats
bars_losses = ax[1].bar(top_5_losses_df['Team'], top_5_losses_df['Losses'], color='red')
ax[1].set_title('Top 5 Teams with the Most Defeats')
ax[1].set_xlabel('Teams')
ax[1].set_ylabel('Number of Defeats')

# Add the values ​​on top of the defeat bars
for bar in bars_losses:
    yval = bar.get_height()
    ax[1].text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')  # va='bottom' coloca o texto acima da barra

# Adjust layout
plt.tight_layout()

# Display the graph
plt.show()

# %% [markdown]
# #### We can see that SK and BDS are the winning team, they will probably face each other in future matches

# %% [markdown]
# #### We can also see that RGE and VIT are the teams with the most defeats, they will probably face each other

# %% [markdown]
# ## And which teams would have the most map vision?

# %%
df_visao_de_jogo = df[['Player', 'Role', 'Team', 'Opponent_Team', 'Opponent_Player', 'Wards placed',
       'Wards destroyed', 'Control Wards Purchased', 'Detector Wards Placed']]

# Group and add metrics for each team
wards_placed = df_visao_de_jogo.groupby('Team')['Wards placed'].sum()
wards_destroyed = df_visao_de_jogo.groupby('Team')['Wards destroyed'].sum()
control_wards_purchased = df_visao_de_jogo.groupby('Team')['Control Wards Purchased'].sum()

# Select the 3 teams with the most values ​​for each metric
top_3_wards_placed = wards_placed.sort_values(ascending=False).head(3)
top_3_wards_destroyed = wards_destroyed.sort_values(ascending=False).head(3)
top_3_control_wards_purchased = control_wards_purchased.sort_values(ascending=False).head(3)

# Create DataFrames for easier viewing
top_3_wards_placed_df = top_3_wards_placed.reset_index()
top_3_wards_destroyed_df = top_3_wards_destroyed.reset_index()
top_3_control_wards_purchased_df = top_3_control_wards_purchased.reset_index()

# Configure the chart
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

# Wards Placed Chart
bars_wards_placed = ax[0].bar(top_3_wards_placed_df['Team'], top_3_wards_placed_df['Wards placed'], color='blue')
ax[0].set_title('Top 3 Teams with Most Wards Placed')
ax[0].set_xlabel('Teams')
ax[0].set_ylabel('Number of Wards Placed')

# Add the values ​​on top of the wards placed bars
for bar in bars_wards_placed:
    yval = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')

# Destroyed Wards Chart
bars_wards_destroyed = ax[1].bar(top_3_wards_destroyed_df['Team'], top_3_wards_destroyed_df['Wards destroyed'], color='orange')
ax[1].set_title('Top 3 Teams with the Most Wards Destroyed')
ax[1].set_xlabel('Teams')
ax[1].set_ylabel('Number of Wards Destroyed')

# Add the values ​​on top of the destroyed wards bars
for bar in bars_wards_destroyed:
    yval = bar.get_height()
    ax[1].text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')

# Control Wards Purchased Chart
bars_control_wards_purchased = ax[2].bar(top_3_control_wards_purchased_df['Team'], top_3_control_wards_purchased_df['Control Wards Purchased'], color='green')
ax[2].set_title('Top 3 Teams with Most Control Wards Purchased')
ax[2].set_xlabel('Teams')
ax[2].set_ylabel('Number of Control Wards Purchased')


# Add the values ​​above the control wards purchased bars
for bar in bars_control_wards_purchased:
    yval = bar.get_height()
    ax[2].text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')

# Adjust layout
plt.tight_layout()

# Display the graph
plt.show()

# %% [markdown]
# #### Looking at this graph you can see that the MDK team has a lot of vision control, but why is it one of the teams that loses the most? It's an interesting question, since game vision is one of the fundamental parts of being a great player.

# %% [markdown]
# ## Let's analyze the team with the most victories

# %% [markdown]
# # Team SK

# %% [markdown]
# ### TOP

# %%
# List of columns to be shown
df_melhor_time_columns = ['Player', 'Role', 'Team', 'Champion', 'Champion_Opponent', 'Kills', 'Deaths', 'Assists', 'KDA', 'Golds', 'Wards placed', 'Ban']

# Filter only data from the SK team to TOP
df_sk_top = df[(df['Team'] == 'SK') & (df['Role'] == 'TOP')].copy()

# Convert KDA to numeric, keeping 'Perfect KDA' as is
df_sk_top['KDA'] = df_sk_top['KDA'].replace('Perfect_KDA', '10.0')
df_sk_top['KDA'] = pd.to_numeric(df_sk_top['KDA'], errors='coerce')

# Find the 4 champions with the best KDA
top_4_top = df_sk_top.sort_values(by='KDA', ascending=False).head(4)

# Show only relevant data
top_4_top_filtered = top_4_top[df_melhor_time_columns]

# Show results
print("Top 4 TOP Champions:")
top_4_top_filtered.head()
# Out:
# Top 4 TOP Champions:
#          Player Role Team Champion Champion_Opponent  Kills  Deaths  Assists  \
# 330  Irrelevant  TOP   SK  Skarner           Sejuani      2       1        9
# 380  Irrelevant  TOP   SK     Gnar            KSante      5       1        6
# 95   Irrelevant  TOP   SK     Gnar            KSante      7       2        3
# 115  Irrelevant  TOP   SK   KSante            Rumble      1       3       11
#
#       KDA    Golds  Wards placed       Ban
# 330  11.0  10354.0           8.0        Vi
# 380  11.0  15812.0          13.0  Nautilus
# 95    5.0  16416.0          19.0  Tristana
# 115   4.0  12577.0          16.0  Nautilus

# %% [markdown]
# ##### We can see that the TOP of SK, a player with a great KDA, used one of the most picked champions, and against Ksante he preferred to choose Gnar, a great character against K'sante

# %% [markdown]
# ### Jungle

# %%
# List of columns to be shown
df_melhor_time_columns = ['Player', 'Role', 'Team', 'Champion', 'Champion_Opponent', 'Kills', 'Deaths', 'Assists', 'KDA', 'Golds', 'Wards placed', 'Ban']

# Filter only SK team data for JUNGLE
df_sk_jg = df[(df['Team'] == 'SK') & (df['Role'] == 'JUNGLE')].copy()

# Convert KDA to numeric, keeping 'Perfect KDA' as is
df_sk_jg['KDA'] = df_sk_jg['KDA'].replace('Perfect_KDA', '10.0')
df_sk_jg['KDA'] = pd.to_numeric(df_sk_jg['KDA'], errors='coerce')

# Find the 4 champions with the best KDA
top_4_top = df_sk_jg.sort_values(by='KDA', ascending=False).head(4)

# Show only relevant data
top_4_top_filtered = top_4_top[df_melhor_time_columns]

# Show results
print("Top 4 JUNGLE Champions:")
top_4_top_filtered.head()
# Out:
# Top 4 JUNGLE Champions:
#     Player    Role Team Champion Champion_Opponent  Kills  Deaths  Assists  \
# 266   Isma  JUNGLE   SK  Sejuani           Karthus      5       1       13
# 11    Isma  JUNGLE   SK    Poppy            RekSai      4       1        8
# 331   Isma  JUNGLE   SK    Diana             Brand      5       2        7
# 381   Isma  JUNGLE   SK   Maokai          Xin_Zhao      3       2        9
#
#       KDA    Golds  Wards placed      Ban
# 266  18.0   9789.0          12.0  Skarner
# 11   12.0  12763.0          16.0  LeBlanc
# 331   6.0  12950.0           6.0    Varus
# 381   6.0  11059.0          13.0    Kaisa

# %% [markdown]
# ##### We can see that Isma stood out well from Sejuani and Poppy with a KDA well above the average of the other matches

# %% [markdown]
# ### MID

# %%
# List of columns to be shown
df_melhor_time_columns = ['Player', 'Role', 'Team', 'Champion', 'Champion_Opponent', 'Kills', 'Deaths', 'Assists', 'KDA', 'Golds', 'Wards placed', 'Ban']

# Filter only SK team data for MID
df_sk_mid = df[(df['Team'] == 'SK') & (df['Role'] == 'MID')].copy()

# Convert KDA to numeric, keeping 'Perfect_KDA' as is
df_sk_mid['KDA'] = df_sk_mid['KDA'].replace('Perfect_KDA', '10.0')
df_sk_mid['KDA'] = pd.to_numeric(df_sk_mid['KDA'], errors='coerce')

# Find the 4 champions with the best KDA
top_4_mid = df_sk_mid.sort_values(by='KDA', ascending=False).head(4)

# Show only relevant data
top_4_mid_filtered = top_4_mid[df_melhor_time_columns]

# Show results
print("Top 4 MID Champions:")
top_4_mid_filtered.head()
# Out:
# Top 4 MID Champions:
#     Player Role Team Champion Champion_Opponent  Kills  Deaths  Assists   KDA  \
# 12   Nisqy  MID   SK  Taliyah             Corki      4       1        7  11.0
# 382  Nisqy  MID   SK  Taliyah              Azir      5       2        3   4.0
# 97   Nisqy  MID   SK     Hwei              Azir      4       2       15   NaN
# 117  Nisqy  MID   SK     Azir           LeBlanc      9       3        7   NaN
#
#        Golds  Wards placed       Ban
# 12   15740.0          22.0  Nautilus
# 382  16136.0          22.0        Vi
# 97   17882.0          26.0   Skarner
# 117  19303.0          21.0     Varus

# %% [markdown]
# ##### Looking at Nisqy, he has a great Taliyah as the win rate should be good with her and good ward control with this character

# %% [markdown]
# ### ADC

# %%
# # List of columns to be shown
df_melhor_time_columns = ['Player', 'Role', 'Team', 'Champion', 'Champion_Opponent', 'Kills', 'Deaths', 'Assists', 'KDA', 'Golds', 'Wards placed', 'Ban']

# Filter only SK team data for ADC
df_sk_adc = df[(df['Team'] == 'SK') & (df['Role'] == 'ADCARRY')].copy()

# Convert KDA to numeric, keeping 'Perfect_KDA' as is
df_sk_adc['KDA'] = df_sk_adc['KDA'].replace('Perfect_KDA', '10.0')
df_sk_adc['KDA'] = pd.to_numeric(df_sk_adc['KDA'], errors='coerce')

# Find the 4 champions with the best KDA
top_4_adc = df_sk_adc.sort_values(by='KDA', ascending=False).head(4)

# Show only relevant data
top_4_adc_filtered = top_4_adc[df_melhor_time_columns]

# Show results
print("Top 4 ADC Champions:")
top_4_adc_filtered.head()
# Out:
# Top 4 ADC Champions:
#     Player     Role Team Champion Champion_Opponent  Kills  Deaths  Assists  \
# 268  Rahel  ADCARRY   SK     Zeri             Kaisa      5       1       12
# 118  Rahel  ADCARRY   SK   Lucian              Zeri      7       1        8
# 158  Rahel  ADCARRY   SK    Kaisa              Jinx      8       1        4
# 333  Rahel  ADCARRY   SK    Kaisa              Zeri      6       1        4
#
#      KDA    Golds  Wards placed     Ban
# 268   17  12147.0          12.0  Maokai
# 118   15  21765.0          17.0  Draven
# 158   12  18463.0          16.0    Olaf
# 333   10  14278.0          15.0    Zyra

# %% [markdown]
# ##### Here we have already noticed a great Zeri, where he had an incredible KDA and probably in Lucian's match, he took it because his opponent must have taken his Zeri, but he is a champion that he should feel comfortable using

# %% [markdown]
# ### SUP

# %%
# # List of columns to be shown
df_melhor_time_columns = ['Player', 'Role', 'Team', 'Champion', 'Champion_Opponent', 'Kills', 'Deaths', 'Assists', 'KDA', 'Golds', 'Wards placed', 'Ban']

# Filter only SK team data for SUP
df_sk_suport = df[(df['Team'] == 'SK') & (df['Role'] == 'SUPPORT')].copy()

# Convert KDA to numeric, keeping 'Perfect_KDA' as is
df_sk_suport['KDA'] = df_sk_suport['KDA'].replace('Perfect_KDA', '10.0')
df_sk_suport['KDA'] = pd.to_numeric(df_sk_suport['KDA'], errors='coerce')

# Find the 4 champions with the best KDA
top_4_sup = df_sk_suport.sort_values(by='KDA', ascending=False).head(4)

# Show only relevant data
top_4_sup_filtered = top_4_sup[df_melhor_time_columns]

# Show results
print("Top 4 SUP Champions:")
top_4_sup_filtered.head()
# Out:
# Top 4 SUP Champions:
#     Player     Role Team Champion Champion_Opponent  Kills  Deaths  Assists  \
# 269   Luon  SUPPORT   SK     Rell            Maokai      2       1       18
# 159   Luon  SUPPORT   SK  Alistar              Rell      0       1       16
# 14    Luon  SUPPORT   SK     Ashe              Rell      2       2       12
# 119   Luon  SUPPORT   SK     Nami             Rakan      0       4       12
#
#       KDA    Golds  Wards placed      Ban
# 269  20.0   7334.0          43.0    Ivern
# 159  16.0   9728.0          78.0    Sylas
# 14    7.0  10505.0          96.0  Orianna
# 119   3.0  10129.0          78.0    Corki

# %% [markdown]
# ##### We noticed that Rell and Alista were played very well by Luon, where his KDA is high, so in future matches with other teams, perhaps some of these two characters will be banned
